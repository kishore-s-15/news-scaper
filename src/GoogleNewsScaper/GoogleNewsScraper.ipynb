# %%
# Importing the required libraries

import sys
import pprint
import logging
from datetime import datetime
from typing import List, Dict, Union

import requests
from bs4 import BeautifulSoup

# %%
# Return type of articles
Articles = Dict[str, Union[str, datetime]]

# %%
class GoogleNewsScraper:
    """
    GoogleNewsScraper scrapes articles from google news rss feeds.
    """

    # Constants
    DATE_TIME_FORMAT = "%a, %d %b %Y %H:%M:%S %Z"
    BASE_URL = "https://news.google.com/rss/search"

    def __init__(self, query: str):
        """
        Constuctor method initializes GoogleNewsScraper object
        to scrape google news rss feeds for the given query.

        Args:
            query (str): Query to scrape.
        """

        self._query = query
        self.url = f"{self.BASE_URL}?q={query}"

        self.setup_logger()

        self.pretty_printer = pprint.PrettyPrinter()

    @property
    def query(self):
        """
        Getter method for _query attribute.
        """

        return self._query

    @query.setter
    def query(self, query_string: str):
        """
        Setter method for _query attribute.

        Args:
            query_string
        """

        query_string_list = query_string.split(" ")
        query_string_list = list(map(lambda x: x.lower(), query_string_list))

        query_string = "+".join(query_string_list)

        self._query = query_string

    def setup_logger(self):
        """
        Method sets up the logger.
        """

        self.logger = logging.getLogger()
        self.logger.setLevel(logging.DEBUG)

        handler = logging.StreamHandler(sys.stdout)
        handler.setLevel(logging.DEBUG)

        formatter = logging.Formatter(
            "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
        )
        handler.setFormatter(formatter)

        self.logger.addHandler(handler)

    def parse_string_to_datetime(self, date_time_str: str) -> datetime:
        """
        Method parses string to python datetime object.

        Args:
            date_time_str (str): Datetime string.

        Returns:
            date_time_obj (datetime): Parsed python datetime object.
        """

        date_time_obj = datetime.strptime(date_time_str, self.DATE_TIME_FORMAT)
        return date_time_obj

    def scrape_articles(self) -> List[Articles]:
        """
        Method scrapes google news rss feed articles.

        Returns:
            articles (List[Articles]): List of scraped articles of type Article.
        """

        self.logger.info(f"Started scraping {self.url}...")

        xml_content = requests.get(self.url).content
        soup = BeautifulSoup(xml_content, features="xml")
        items = soup.find_all("item")

        self.logger.info(f"Scraped {len(items)} articles.")

        articles: List[Articles] = []

        for item in items:
            article = {}

            # Articles Info
            article["link"] = item.find("link").text
            article["title"] = item.find("title").text
            article["description"] = item.find("description").text

            # Publisher info
            article["publisher"] = item.find("source").text
            article["published_date"] = self.parse_string_to_datetime(
                item.find("pubDate").text
            )

            articles.append(article)

        return articles

    def print_articles(self, articles: List[Articles]):
        """
        Method pretty prints scraped articles.

        Args:
            articles (List[Articles]): Scraped Articles.
        """

        self.pretty_printer.pprint(articles)

# %%
query = "Carbon Net Zero"

# %%
google_scaper = GoogleNewsScraper(query)

# %%
articles = google_scaper.scrape_articles()
# Out:
# 2022-06-06 12:21:47,468 - root - INFO - Started scraping https://news.google.com/rss/search?q=Carbon Net Zero...
# 2022-06-06 12:21:47,471 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): news.google.com:443
# 2022-06-06 12:21:47,738 - urllib3.connectionpool - DEBUG - https://news.google.com:443 "GET /rss/search?q=Carbon%20Net%20Zero HTTP/1.1" 302 0
# 2022-06-06 12:21:48,339 - urllib3.connectionpool - DEBUG - https://news.google.com:443 "GET /rss/search?q=Carbon+Net+Zero&hl=en-IN&gl=IN&ceid=IN:en HTTP/1.1" 200 None
# 2022-06-06 12:21:48,373 - root - INFO - Scraped 99 articles.

# %%
google_scaper.print_articles(articles)
# Out:
# [{'description': '<a '
#                  'href="https://www.thehindubusinessline.com/specials/clean-tech/carbon-credits-could-boom-in-the-age-of-net-zero/article65468468.ece" '
#                  'target="_blank">Carbon credits could boom in the age of net '
#                  'zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">BusinessLine</font>',
#   'link': 'https://www.thehindubusinessline.com/specials/clean-tech/carbon-credits-could-boom-in-the-age-of-net-zero/article65468468.ece',
#   'published_date': datetime.datetime(2022, 5, 29, 15, 47, 9),
#   'publisher': 'BusinessLine',
#   'title': 'Carbon credits could boom in the age of net zero - BusinessLine'},
#  {'description': '<a '
#                  'href="https://www.weforum.org/agenda/2022/05/carbon-credits-could-help-india-reach-net-zero-2070/" '
#                  'target="_blank">Carbon credits could help India reach '
#                  'net-zero by 2070</a>&nbsp;&nbsp;<font color="#6f6f6f">World '
#                  'Economic Forum</font>',
#   'link': 'https://www.weforum.org/agenda/2022/05/carbon-credits-could-help-india-reach-net-zero-2070/',
#   'published_date': datetime.datetime(2022, 5, 18, 7, 0),
#   'publisher': 'World Economic Forum',
#   'title': 'Carbon credits could help India reach net-zero by 2070 - World '
#            'Economic Forum'},
#  {'description': '<a '
#                  'href="https://www.indiatoday.in/india/story/net-zero-emissions-gujarat-govt-mou-set-up-first-carbon-market-1953232-2022-05-24" '
#                  'target="_blank">Target net-zero emissions: Gujarat govt '
#                  'signs MOU to set up first carbon market</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">India Today</font>',
#   'link': 'https://www.indiatoday.in/india/story/net-zero-emissions-gujarat-govt-mou-set-up-first-carbon-market-1953232-2022-05-24',
#   'published_date': datetime.datetime(2022, 5, 24, 7, 0),
#   'publisher': 'India Today',
#   'title': 'Target net-zero emissions: Gujarat govt signs MOU to set up first '
#            'carbon market - India Today'},
#  {'description': '<a '
#                  'href="https://timesofindia.indiatimes.com/city/kanpur/india-will-try-to-become-net-zero-emission-economy/articleshow/92011855.cms" '
#                  'target="_blank">‘India will try to become net zero emission '
#                  'economy’</a>&nbsp;&nbsp;<font color="#6f6f6f">Times of '
#                  'India</font>',
#   'link': 'https://timesofindia.indiatimes.com/city/kanpur/india-will-try-to-become-net-zero-emission-economy/articleshow/92011855.cms',
#   'published_date': datetime.datetime(2022, 6, 4, 21, 42),
#   'publisher': 'Times of India',
#   'title': '‘India will try to become net zero emission economy’ - Times of '
#            'India'},
#  {'description': '<a '
#                  'href="https://www.weforum.org/agenda/2022/05/how-are-companies-accelerating-their-commitments-to-net-zero-5-ceos-share-their-strategies-52b79ad93c/" '
#                  'target="_blank">6 CEOs share how their companies are '
#                  'targeting net-zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">World Economic Forum</font>',
#   'link': 'https://www.weforum.org/agenda/2022/05/how-are-companies-accelerating-their-commitments-to-net-zero-5-ceos-share-their-strategies-52b79ad93c/',
#   'published_date': datetime.datetime(2022, 5, 19, 7, 0),
#   'publisher': 'World Economic Forum',
#   'title': '6 CEOs share how their companies are targeting net-zero - World '
#            'Economic Forum'},
#  {'description': '<a '
#                  'href="https://www.businesswire.com/news/home/20220519005482/en/%C2%A0FEELM-Commits-to-Net-zero-Carbon-Emissions-By-2050" '
#                  'target="_blank">FEELM Commits to Net-zero Carbon Emissions '
#                  'By 2050</a>&nbsp;&nbsp;<font color="#6f6f6f">Business '
#                  'Wire</font>',
#   'link': 'https://www.businesswire.com/news/home/20220519005482/en/%C2%A0FEELM-Commits-to-Net-zero-Carbon-Emissions-By-2050',
#   'published_date': datetime.datetime(2022, 5, 19, 7, 0),
#   'publisher': 'Business Wire',
#   'title': 'FEELM Commits to Net-zero Carbon Emissions By 2050 - Business '
#            'Wire'},
#  {'description': '<a '
#                  'href="https://www.fortuneindia.com/multimedia/smes-struggle-to-achieve-carbon-net-zero-ciis-sanjiv-bajaj/108306" '
#                  'target="_blank">SMEs struggle to achieve carbon net-zero: '
#                  'CII’s Sanjiv Bajaj</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Fortune India</font>',
#   'link': 'https://www.fortuneindia.com/multimedia/smes-struggle-to-achieve-carbon-net-zero-ciis-sanjiv-bajaj/108306',
#   'published_date': datetime.datetime(2022, 5, 24, 6, 9, 25),
#   'publisher': 'Fortune India',
#   'title': 'SMEs struggle to achieve carbon net-zero: CII’s Sanjiv Bajaj - '
#            'Fortune India'},
#  {'description': '<a '
#                  'href="https://www.gov.uk/government/case-studies/net-zero-programme-looking-beyond-carbon-emissions" '
#                  'target="_blank">NET ZERO PROGRAMME: Looking beyond carbon '
#                  'emissions - Case study</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">GOV.UK</font>',
#   'link': 'https://www.gov.uk/government/case-studies/net-zero-programme-looking-beyond-carbon-emissions',
#   'published_date': datetime.datetime(2022, 5, 11, 7, 0),
#   'publisher': 'GOV.UK',
#   'title': 'NET ZERO PROGRAMME: Looking beyond carbon emissions - Case study - '
#            'GOV.UK'},
#  {'description': '<a '
#                  'href="https://analyticsindiamag.com/the-indian-it-and-carbon-neutrality/" '
#                  'target="_blank">The Indian IT and carbon '
#                  'neutrality</a>&nbsp;&nbsp;<font color="#6f6f6f">Analytics '
#                  'India Magazine</font>',
#   'link': 'https://analyticsindiamag.com/the-indian-it-and-carbon-neutrality/',
#   'published_date': datetime.datetime(2022, 5, 30, 5, 33, 4),
#   'publisher': 'Analytics India Magazine',
#   'title': 'The Indian IT and carbon neutrality - Analytics India Magazine'},
#  {'description': '<a '
#                  'href="https://www.foodnavigator.com/Article/2022/05/12/Carbon-neutral-vs-net-zero-Which-approach-are-start-ups-taking-and-why" '
#                  'target="_blank">Carbon neutral vs net-zero: Which approach '
#                  'are start-ups taking and why?</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">FoodNavigator.com</font>',
#   'link': 'https://www.foodnavigator.com/Article/2022/05/12/Carbon-neutral-vs-net-zero-Which-approach-are-start-ups-taking-and-why',
#   'published_date': datetime.datetime(2022, 5, 13, 7, 0),
#   'publisher': 'FoodNavigator.com',
#   'title': 'Carbon neutral vs net-zero: Which approach are start-ups taking '
#            'and why? - FoodNavigator.com'},
#  {'description': '<a '
#                  'href="https://www.world-grain.com/articles/16988-viterra-targets-carbon-net-zero-by-2050" '
#                  'target="_blank">Viterra targets carbon net zero by '
#                  '2050</a>&nbsp;&nbsp;<font color="#6f6f6f">World Grain</font>',
#   'link': 'https://www.world-grain.com/articles/16988-viterra-targets-carbon-net-zero-by-2050',
#   'published_date': datetime.datetime(2022, 6, 2, 13, 5, 36),
#   'publisher': 'World Grain',
#   'title': 'Viterra targets carbon net zero by 2050 - World Grain'},
#  {'description': '<a '
#                  'href="https://theprint.in/environment/reward-indian-farmers-with-carbon-credits-net-zero-hinges-on-climate-friendly-practices/964344/" '
#                  'target="_blank">Reward Indian farmers with ‘carbon credits’. '
#                  'Net-zero hinges on climate-friendly '
#                  'practices</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">ThePrint</font>',
#   'link': 'https://theprint.in/environment/reward-indian-farmers-with-carbon-credits-net-zero-hinges-on-climate-friendly-practices/964344/',
#   'published_date': datetime.datetime(2022, 5, 21, 7, 0),
#   'publisher': 'ThePrint',
#   'title': 'Reward Indian farmers with ‘carbon credits’. Net-zero hinges on '
#            'climate-friendly practices - ThePrint'},
#  {'description': '<a '
#                  'href="https://www.theguardian.com/environment/2022/may/30/greenhouse-gas-removal-not-a-silver-bullet-to-achieve-net-zero" '
#                  'target="_blank">Greenhouse gas removal ‘not a silver bullet '
#                  'to achieve net zero’</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Guardian</font>',
#   'link': 'https://www.theguardian.com/environment/2022/may/30/greenhouse-gas-removal-not-a-silver-bullet-to-achieve-net-zero',
#   'published_date': datetime.datetime(2022, 5, 31, 10, 26),
#   'publisher': 'The Guardian',
#   'title': 'Greenhouse gas removal ‘not a silver bullet to achieve net zero’ - '
#            'The Guardian'},
#  {'description': '<a '
#                  'href="https://napavalleyregister.com/opinion/letters/letter-working-toward-net-zero-carbon-emissions/article_2186c8b2-e392-11ec-b6f1-67ebe96e53b3.html" '
#                  'target="_blank">Letter: Working toward net-zero carbon '
#                  'emissions | Letters to the Editor | '
#                  'napavalleyregister.com</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Napa Valley Register</font>',
#   'link': 'https://napavalleyregister.com/opinion/letters/letter-working-toward-net-zero-carbon-emissions/article_2186c8b2-e392-11ec-b6f1-67ebe96e53b3.html',
#   'published_date': datetime.datetime(2022, 6, 5, 8, 30),
#   'publisher': 'Napa Valley Register',
#   'title': 'Letter: Working toward net-zero carbon emissions | Letters to the '
#            'Editor | napavalleyregister.com - Napa Valley Register'},
#  {'description': '<a '
#                  'href="https://www.freightwaves.com/news/how-hydrogen-could-help-decarbonize-transportation-net-zero-carbon" '
#                  'target="_blank">How hydrogen could help decarbonize '
#                  'transportation — Net-Zero Carbon</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">FreightWaves</font>',
#   'link': 'https://www.freightwaves.com/news/how-hydrogen-could-help-decarbonize-transportation-net-zero-carbon',
#   'published_date': datetime.datetime(2022, 5, 31, 14, 42, 5),
#   'publisher': 'FreightWaves',
#   'title': 'How hydrogen could help decarbonize transportation — Net-Zero '
#            'Carbon - FreightWaves'},
#  {'description': '<a '
#                  'href="https://www.energyvoice.com/promoted/415230/supply-chain-partners-are-the-key-to-unlocking-net-zero-success/" '
#                  'target="_blank">Supply chain partners are the key to '
#                  'unlocking net zero success</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Energy Voice</font>',
#   'link': 'https://www.energyvoice.com/promoted/415230/supply-chain-partners-are-the-key-to-unlocking-net-zero-success/',
#   'published_date': datetime.datetime(2022, 6, 6, 6, 10, 36),
#   'publisher': 'Energy Voice',
#   'title': 'Supply chain partners are the key to unlocking net zero success - '
#            'Energy Voice'},
#  {'description': '<a '
#                  'href="https://energy.economictimes.indiatimes.com/news/renewable/india-to-meet-50-per-cent-of-its-energy-needs-from-renewable-resources-by-2030-minister/92026761" '
#                  'target="_blank">India to meet 50 per cent of its energy '
#                  'needs from renewable resources by 2030: '
#                  'Minister</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">ETEnergyWorld</font>',
#   'link': 'https://energy.economictimes.indiatimes.com/news/renewable/india-to-meet-50-per-cent-of-its-energy-needs-from-renewable-resources-by-2030-minister/92026761',
#   'published_date': datetime.datetime(2022, 6, 6, 1, 45),
#   'publisher': 'ETEnergyWorld',
#   'title': 'India to meet 50 per cent of its energy needs from renewable '
#            'resources by 2030: Minister - ETEnergyWorld'},
#  {'description': '<a '
#                  'href="https://www.bloomberg.com/news/articles/2022-05-09/new-zealand-sets-emissions-targets-in-pursuit-of-net-zero-carbon" '
#                  'target="_blank">New Zealand Sets Emissions Targets In '
#                  'Pursuit of Net-Zero Carbon</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Bloomberg</font>',
#   'link': 'https://www.bloomberg.com/news/articles/2022-05-09/new-zealand-sets-emissions-targets-in-pursuit-of-net-zero-carbon',
#   'published_date': datetime.datetime(2022, 5, 8, 7, 0),
#   'publisher': 'Bloomberg',
#   'title': 'New Zealand Sets Emissions Targets In Pursuit of Net-Zero Carbon - '
#            'Bloomberg'},
#  {'description': '<a '
#                  'href="https://www.powermag.com/is-carbon-management-the-key-to-reaching-net-zero/" '
#                  'target="_blank">Is Carbon Management the Key to Reaching Net '
#                  'Zero?</a>&nbsp;&nbsp;<font color="#6f6f6f">POWER '
#                  'magazine</font>',
#   'link': 'https://www.powermag.com/is-carbon-management-the-key-to-reaching-net-zero/',
#   'published_date': datetime.datetime(2022, 5, 23, 7, 0),
#   'publisher': 'POWER magazine',
#   'title': 'Is Carbon Management the Key to Reaching Net Zero? - POWER '
#            'magazine'},
#  {'description': '<a '
#                  'href="https://www.akdn.org/our-stories/achieving-net-zero-how-our-health-operations-are-slashing-carbon-emissions-while-saving" '
#                  'target="_blank">Achieving net zero: How our health '
#                  'operations are slashing carbon emissions while saving '
#                  'thousands | Aga Khan Development '
#                  'Network</a>&nbsp;&nbsp;<font color="#6f6f6f">Aga Khan '
#                  'Development Network |</font>',
#   'link': 'https://www.akdn.org/our-stories/achieving-net-zero-how-our-health-operations-are-slashing-carbon-emissions-while-saving',
#   'published_date': datetime.datetime(2022, 6, 3, 19, 7, 56),
#   'publisher': 'Aga Khan Development Network |',
#   'title': 'Achieving net zero: How our health operations are slashing carbon '
#            'emissions while saving thousands | Aga Khan Development Network - '
#            'Aga Khan Development Network |'},
#  {'description': '<a '
#                  'href="https://timesofindia.indiatimes.com/business/india-business/leed-certifies-3-itc-hotels-as-net-zero-carbon-properties/articleshow/91991665.cms" '
#                  'target="_blank">LEED certifies 3 ITC hotels as \'net zero '
#                  "carbon' properties</a>&nbsp;&nbsp;<font "
#                  'color="#6f6f6f">Times of India</font>',
#   'link': 'https://timesofindia.indiatimes.com/business/india-business/leed-certifies-3-itc-hotels-as-net-zero-carbon-properties/articleshow/91991665.cms',
#   'published_date': datetime.datetime(2022, 6, 3, 16, 11),
#   'publisher': 'Times of India',
#   'title': "LEED certifies 3 ITC hotels as 'net zero carbon' properties - "
#            'Times of India'},
#  {'description': '<a '
#                  'href="https://www.thehindubusinessline.com/news/indian-leather-industry-must-seek-net-zero-carbon-footprint-jitendra-singh/article65429979.ece" '
#                  'target="_blank">Indian leather industry must seek net-zero '
#                  'carbon footprint: Jitendra Singh</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">BusinessLine</font>',
#   'link': 'https://www.thehindubusinessline.com/news/indian-leather-industry-must-seek-net-zero-carbon-footprint-jitendra-singh/article65429979.ece',
#   'published_date': datetime.datetime(2022, 5, 19, 7, 0),
#   'publisher': 'BusinessLine',
#   'title': 'Indian leather industry must seek net-zero carbon footprint: '
#            'Jitendra Singh - BusinessLine'},
#  {'description': '<a '
#                  'href="https://www.freightwaves.com/news/scaling-low-carbon-logistics-solutions-net-zero-carbon" '
#                  'target="_blank">Scaling low-carbon logistics solutions — '
#                  'Net-Zero Carbon</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">FreightWaves</font>',
#   'link': 'https://www.freightwaves.com/news/scaling-low-carbon-logistics-solutions-net-zero-carbon',
#   'published_date': datetime.datetime(2022, 5, 17, 7, 0),
#   'publisher': 'FreightWaves',
#   'title': 'Scaling low-carbon logistics solutions — Net-Zero Carbon - '
#            'FreightWaves'},
#  {'description': '<a '
#                  'href="https://www.washingtonpost.com/world/2022/06/01/environmental-performance-index-climate-change-emissions-ranking/" '
#                  'target="_blank">Report: Denmark, U.K. on track for net-zero '
#                  'emissions by 2050 as U.S. lags</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Washington Post</font>',
#   'link': 'https://www.washingtonpost.com/world/2022/06/01/environmental-performance-index-climate-change-emissions-ranking/',
#   'published_date': datetime.datetime(2022, 6, 1, 22, 40),
#   'publisher': 'The Washington Post',
#   'title': 'Report: Denmark, U.K. on track for net-zero emissions by 2050 as '
#            'U.S. lags - The Washington Post'},
#  {'description': '<a '
#                  'href="https://www.edie.net/virgin-money-launches-200m-agri-fund-to-help-farmers-reach-net-zero/" '
#                  'target="_blank">Virgin Money launches £200m agri-fund to '
#                  'help farmers reach net-zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">edie.net</font>',
#   'link': 'https://www.edie.net/virgin-money-launches-200m-agri-fund-to-help-farmers-reach-net-zero/',
#   'published_date': datetime.datetime(2022, 6, 1, 8, 42, 37),
#   'publisher': 'edie.net',
#   'title': 'Virgin Money launches £200m agri-fund to help farmers reach '
#            'net-zero - edie.net'},
#  {'description': '<a '
#                  'href="https://www.forbes.com/sites/leannekemp/2022/05/29/crypto-carbon-credits-the-canary-in-the-coal-mine-in-the-race-to-net-zero/" '
#                  'target="_blank">Crypto Carbon Credits: The Canary In The '
#                  'Coal Mine In The Race To Net Zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Forbes</font>',
#   'link': 'https://www.forbes.com/sites/leannekemp/2022/05/29/crypto-carbon-credits-the-canary-in-the-coal-mine-in-the-race-to-net-zero/',
#   'published_date': datetime.datetime(2022, 5, 29, 23, 24, 47),
#   'publisher': 'Forbes',
#   'title': 'Crypto Carbon Credits: The Canary In The Coal Mine In The Race To '
#            'Net Zero - Forbes'},
#  {'description': '<a '
#                  'href="https://theprovince.com/opinion/jeremy-van-loon-forests-could-tip-the-carbon-scales-either-way-on-canadas-path-to-net-zero" '
#                  'target="_blank">Jeremy van Loon: Forests could tip the '
#                  "carbon scales either way on Canada's path to "
#                  'net-zero</a>&nbsp;&nbsp;<font color="#6f6f6f">The '
#                  'Province</font>',
#   'link': 'https://theprovince.com/opinion/jeremy-van-loon-forests-could-tip-the-carbon-scales-either-way-on-canadas-path-to-net-zero',
#   'published_date': datetime.datetime(2022, 6, 5, 1, 6, 58),
#   'publisher': 'The Province',
#   'title': 'Jeremy van Loon: Forests could tip the carbon scales either way on '
#            "Canada's path to net-zero - The Province"},
#  {'description': '<a '
#                  'href="https://www.carbonbrief.org/greenhouse-gas-removal-how-could-it-help-the-uk-reach-net-zero-by-2050/" '
#                  'target="_blank">Greenhouse gas removal: How could it help '
#                  'the UK reach net-zero by 2050?</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Carbon Brief</font>',
#   'link': 'https://www.carbonbrief.org/greenhouse-gas-removal-how-could-it-help-the-uk-reach-net-zero-by-2050/',
#   'published_date': datetime.datetime(2022, 5, 17, 7, 0),
#   'publisher': 'Carbon Brief',
#   'title': 'Greenhouse gas removal: How could it help the UK reach net-zero by '
#            '2050? - Carbon Brief'},
#  {'description': '<a '
#                  'href="https://www.thehansindia.com/business/i-always-wanted-to-make-an-ac-which-doesnt-dig-hole-in-pockets-exalta-founder-747016" '
#                  'target="_blank">I always wanted to make an AC which doesnt '
#                  'dig hole in pockets: Exalta founder</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Hans India</font>',
#   'link': 'https://www.thehansindia.com/business/i-always-wanted-to-make-an-ac-which-doesnt-dig-hole-in-pockets-exalta-founder-747016',
#   'published_date': datetime.datetime(2022, 6, 5, 21, 3, 1),
#   'publisher': 'The Hans India',
#   'title': 'I always wanted to make an AC which doesnt dig hole in pockets: '
#            'Exalta founder - The Hans India'},
#  {'description': '<a '
#                  'href="https://www.livemint.com/industry/india-could-gain-11-trillion-by-2070-by-transitioning-to-green-economy-report-11654164270581.html" '
#                  'target="_blank">India Could Gain $11 Trillion By 2070 By '
#                  'Transitioning To Green Economy: Report | '
#                  'Mint</a>&nbsp;&nbsp;<font color="#6f6f6f">Mint</font>',
#   'link': 'https://www.livemint.com/industry/india-could-gain-11-trillion-by-2070-by-transitioning-to-green-economy-report-11654164270581.html',
#   'published_date': datetime.datetime(2022, 6, 2, 10, 21, 40),
#   'publisher': 'Mint',
#   'title': 'India Could Gain $11 Trillion By 2070 By Transitioning To Green '
#            'Economy: Report | Mint - Mint'},
#  {'description': '<a '
#                  'href="https://www.huawei.com/en/news/2022/6/wsis-champion-netzero-yancheng" '
#                  'target="_blank">Huawei Intelligent Net-Zero Carbon Campus '
#                  'Solution Wins WSIS Prize 2022 Champion</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Huawei</font>',
#   'link': 'https://www.huawei.com/en/news/2022/6/wsis-champion-netzero-yancheng',
#   'published_date': datetime.datetime(2022, 6, 1, 16, 22, 5),
#   'publisher': 'Huawei',
#   'title': 'Huawei Intelligent Net-Zero Carbon Campus Solution Wins WSIS Prize '
#            '2022 Champion - Huawei'},
#  {'description': '<a '
#                  'href="https://www.marketwatch.com/story/qantas-super-allocates-a-2-billion-to-achieve-zero-carbon-emission-goal-by-2050-271654483147" '
#                  'target="_blank">Qantas Super Allocates A$2 Billion to '
#                  'Achieve Zero Carbon Emission Goal by '
#                  '2050</a>&nbsp;&nbsp;<font color="#6f6f6f">MarketWatch</font>',
#   'link': 'https://www.marketwatch.com/story/qantas-super-allocates-a-2-billion-to-achieve-zero-carbon-emission-goal-by-2050-271654483147',
#   'published_date': datetime.datetime(2022, 6, 6, 2, 39),
#   'publisher': 'MarketWatch',
#   'title': 'Qantas Super Allocates A$2 Billion to Achieve Zero Carbon Emission '
#            'Goal by 2050 - MarketWatch'},
#  {'description': '<a '
#                  'href="https://www.treehugger.com/cambridge-engineers-develop-zero-carbon-cement-5323668" '
#                  'target="_blank">Engineers Create Zero Carbon Cement That '
#                  'Could Rewrite Course of Concrete and '
#                  'Steel</a>&nbsp;&nbsp;<font color="#6f6f6f">Treehugger</font>',
#   'link': 'https://www.treehugger.com/cambridge-engineers-develop-zero-carbon-cement-5323668',
#   'published_date': datetime.datetime(2022, 5, 30, 13, 30, 23),
#   'publisher': 'Treehugger',
#   'title': 'Engineers Create Zero Carbon Cement That Could Rewrite Course of '
#            'Concrete and Steel - Treehugger'},
#  {'description': '<a '
#                  'href="https://www.outlookindia.com/business-spotlight/how-tech-companies-can-go-surgical-about-their-net-zero-ambitions-news-199497" '
#                  'target="_blank">How Tech Companies Can Go Surgical About '
#                  'Their Net-Zero Ambitions</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Outlook India</font>',
#   'link': 'https://www.outlookindia.com/business-spotlight/how-tech-companies-can-go-surgical-about-their-net-zero-ambitions-news-199497',
#   'published_date': datetime.datetime(2022, 5, 31, 10, 30, 54),
#   'publisher': 'Outlook India',
#   'title': 'How Tech Companies Can Go Surgical About Their Net-Zero Ambitions '
#            '- Outlook India'},
#  {'description': '<a '
#                  'href="https://www.eurogamer.net/sony-accelerates-net-zero-carbon-and-energy-initiatives-by-10-years" '
#                  'target="_blank">Sony accelerates net zero carbon and energy '
#                  'initiatives by 10 years</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Eurogamer.net</font>',
#   'link': 'https://www.eurogamer.net/sony-accelerates-net-zero-carbon-and-energy-initiatives-by-10-years',
#   'published_date': datetime.datetime(2022, 5, 18, 7, 0),
#   'publisher': 'Eurogamer.net',
#   'title': 'Sony accelerates net zero carbon and energy initiatives by 10 '
#            'years - Eurogamer.net'},
#  {'description': '<a href="http://www.tradearabia.com/news/HEAL_397128.html" '
#                  'target="_blank">All projects to be climate positive for '
#                  'operation by 2040: CRTKL</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Trade Arabia</font>',
#   'link': 'http://www.tradearabia.com/news/HEAL_397128.html',
#   'published_date': datetime.datetime(2022, 6, 5, 17, 19, 2),
#   'publisher': 'Trade Arabia',
#   'title': 'All projects to be climate positive for operation by 2040: CRTKL - '
#            'Trade Arabia'},
#  {'description': '<a '
#                  'href="https://www.aljazeera.com/news/2022/6/5/infographic-how-can-you-reduce-your-carbon-footprint" '
#                  'target="_blank">Infographic: How can you reduce your carbon '
#                  'footprint?</a>&nbsp;&nbsp;<font color="#6f6f6f">Al Jazeera '
#                  'English</font>',
#   'link': 'https://www.aljazeera.com/news/2022/6/5/infographic-how-can-you-reduce-your-carbon-footprint',
#   'published_date': datetime.datetime(2022, 6, 5, 12, 50, 6),
#   'publisher': 'Al Jazeera English',
#   'title': 'Infographic: How can you reduce your carbon footprint? - Al '
#            'Jazeera English'},
#  {'description': '<a '
#                  'href="https://harbourtimes.com/2022/06/02/bud-apac-reinforces-net-zero-ambition-with-jinzhou-brewery-becoming-carbon-neutral-in-2022/" '
#                  'target="_blank">Bud APAC Reinforces Net Zero Ambition with '
#                  'Jinzhou Brewery Becoming Carbon Neutral in '
#                  '2022</a>&nbsp;&nbsp;<font color="#6f6f6f">Harbour '
#                  'Times</font>',
#   'link': 'https://harbourtimes.com/2022/06/02/bud-apac-reinforces-net-zero-ambition-with-jinzhou-brewery-becoming-carbon-neutral-in-2022/',
#   'published_date': datetime.datetime(2022, 6, 2, 23, 17, 57),
#   'publisher': 'Harbour Times',
#   'title': 'Bud APAC Reinforces Net Zero Ambition with Jinzhou Brewery '
#            'Becoming Carbon Neutral in 2022 - Harbour Times'},
#  {'description': '<a '
#                  'href="https://procurementleaders.com/content/schneider-electric-sustainabile-procurement-strategy-net-zero/" '
#                  'target="_blank">Schneider Electric\'s Strategy for a '
#                  'Net-Zero Future</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Procurement Leaders News</font>',
#   'link': 'https://procurementleaders.com/content/schneider-electric-sustainabile-procurement-strategy-net-zero/',
#   'published_date': datetime.datetime(2022, 6, 1, 12, 48, 19),
#   'publisher': 'Procurement Leaders News',
#   'title': "Schneider Electric's Strategy for a Net-Zero Future - Procurement "
#            'Leaders News'},
#  {'description': '<a '
#                  'href="https://www.newscientist.com/article/2322827-uk-government-faces-legal-challenges-over-net-zero-climate-plan/" '
#                  'target="_blank">UK government faces legal challenges over '
#                  'net-zero climate plan</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">New Scientist</font>',
#   'link': 'https://www.newscientist.com/article/2322827-uk-government-faces-legal-challenges-over-net-zero-climate-plan/',
#   'published_date': datetime.datetime(2022, 6, 1, 15, 30, 19),
#   'publisher': 'New Scientist',
#   'title': 'UK government faces legal challenges over net-zero climate plan - '
#            'New Scientist'},
#  {'description': '<a '
#                  'href="https://theconversation.com/beccs-the-carbon-capture-technology-the-uk-is-relying-on-to-reach-net-zero-182176" '
#                  'target="_blank">BECCS: the carbon capture technology the UK '
#                  'is relying on to reach net zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Conversation</font>',
#   'link': 'https://theconversation.com/beccs-the-carbon-capture-technology-the-uk-is-relying-on-to-reach-net-zero-182176',
#   'published_date': datetime.datetime(2022, 5, 17, 7, 0),
#   'publisher': 'The Conversation',
#   'title': 'BECCS: the carbon capture technology the UK is relying on to reach '
#            'net zero - The Conversation'},
#  {'description': '<a '
#                  'href="https://www.hindustantimes.com/ht-insight/climate-change/governments-and-industry-must-collaborate-to-protect-the-environment-101654402268799.html" '
#                  'target="_blank">Governments and industry must collaborate to '
#                  'protect the environment</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Hindustan Times</font>',
#   'link': 'https://www.hindustantimes.com/ht-insight/climate-change/governments-and-industry-must-collaborate-to-protect-the-environment-101654402268799.html',
#   'published_date': datetime.datetime(2022, 6, 5, 4, 19, 19),
#   'publisher': 'Hindustan Times',
#   'title': 'Governments and industry must collaborate to protect the '
#            'environment - Hindustan Times'},
#  {'description': '<a '
#                  'href="https://www.financialexpress.com/industry/sustainable-real-estate-net-zero-projects-define-new-landscape-for-realty-in-india/2541134/" '
#                  'target="_blank">Sustainable real estate: Net-zero projects '
#                  'define new landscape for realty in '
#                  'India</a>&nbsp;&nbsp;<font color="#6f6f6f">The Financial '
#                  'Express</font>',
#   'link': 'https://www.financialexpress.com/industry/sustainable-real-estate-net-zero-projects-define-new-landscape-for-realty-in-india/2541134/',
#   'published_date': datetime.datetime(2022, 5, 29, 0, 45),
#   'publisher': 'The Financial Express',
#   'title': 'Sustainable real estate: Net-zero projects define new landscape '
#            'for realty in India - The Financial Express'},
#  {'description': '<a '
#                  'href="https://www.scotsman.com/country-and-farming/farming-scotsheep-event-highlights-net-zero-carbon-audits-3718014" '
#                  'target="_blank">Farming: Scotsheep event highlights net zero '
#                  'carbon audits</a>&nbsp;&nbsp;<font color="#6f6f6f">The '
#                  'Scotsman</font>',
#   'link': 'https://www.scotsman.com/country-and-farming/farming-scotsheep-event-highlights-net-zero-carbon-audits-3718014',
#   'published_date': datetime.datetime(2022, 6, 2, 6, 0, 55),
#   'publisher': 'The Scotsman',
#   'title': 'Farming: Scotsheep event highlights net zero carbon audits - The '
#            'Scotsman'},
#  {'description': '<a '
#                  'href="https://www.hellenicshippingnews.com/ahead-of-schedule-port-moves-forward-on-net-zero-carbon-goal-with-clean-power-agreement/" '
#                  'target="_blank">Ahead of Schedule, Port Moves Forward on '
#                  'Net-Zero Carbon Goal with Clean Power '
#                  'Agreement</a>&nbsp;&nbsp;<font color="#6f6f6f">Hellenic '
#                  'Shipping News Worldwide</font>',
#   'link': 'https://www.hellenicshippingnews.com/ahead-of-schedule-port-moves-forward-on-net-zero-carbon-goal-with-clean-power-agreement/',
#   'published_date': datetime.datetime(2022, 5, 29, 18, 0, 31),
#   'publisher': 'Hellenic Shipping News Worldwide',
#   'title': 'Ahead of Schedule, Port Moves Forward on Net-Zero Carbon Goal with '
#            'Clean Power Agreement - Hellenic Shipping News Worldwide'},
#  {'description': '<a '
#                  'href="https://www.cambridgeday.com/2022/05/25/on-pursuing-carbon-net-zero-goals-and-offsets-some-proposals-take-us-in-the-wrong-direction/" '
#                  'target="_blank">On pursuing carbon net zero goals and '
#                  'offsets, some proposals take us in the wrong '
#                  'direction</a>&nbsp;&nbsp;<font color="#6f6f6f">Cambridge '
#                  'Day</font>',
#   'link': 'https://www.cambridgeday.com/2022/05/25/on-pursuing-carbon-net-zero-goals-and-offsets-some-proposals-take-us-in-the-wrong-direction/',
#   'published_date': datetime.datetime(2022, 5, 25, 7, 0),
#   'publisher': 'Cambridge Day',
#   'title': 'On pursuing carbon net zero goals and offsets, some proposals take '
#            'us in the wrong direction - Cambridge Day'},
#  {'description': '<a '
#                  'href="https://www.freepressjournal.in/business/startup-woce-announces-platform-to-capture-calculate-and-offset-carbon-footprint" '
#                  'target="_blank">Startup WOCE announces platform to capture, '
#                  'calculate and offset carbon footprint</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Free Press Journal</font>',
#   'link': 'https://www.freepressjournal.in/business/startup-woce-announces-platform-to-capture-calculate-and-offset-carbon-footprint',
#   'published_date': datetime.datetime(2022, 6, 3, 7, 52, 48),
#   'publisher': 'Free Press Journal',
#   'title': 'Startup WOCE announces platform to capture, calculate and offset '
#            'carbon footprint - Free Press Journal'},
#  {'description': '<a '
#                  'href="https://indianexpress.com/article/india/developed-world-should-take-lead-in-transition-towards-net-zero-india-7948232/" '
#                  'target="_blank">Developed world should take lead in '
#                  'transition towards net zero: India</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Indian Express</font>',
#   'link': 'https://indianexpress.com/article/india/developed-world-should-take-lead-in-transition-towards-net-zero-india-7948232/',
#   'published_date': datetime.datetime(2022, 6, 2, 1, 25, 23),
#   'publisher': 'The Indian Express',
#   'title': 'Developed world should take lead in transition towards net zero: '
#            'India - The Indian Express'},
#  {'description': '<a '
#                  'href="https://www.hindustantimes.com/lifestyle/art-culture/world-environment-day-2022-want-to-go-economical-and-eco-friendly-while-constructing-homes-opt-for-green-cement-the-future-of-sustainable-construction-101654438674435.html" '
#                  'target="_blank">Go economical and eco-friendly by '
#                  'constructing home with Green Cement</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Hindustan Times</font>',
#   'link': 'https://www.hindustantimes.com/lifestyle/art-culture/world-environment-day-2022-want-to-go-economical-and-eco-friendly-while-constructing-homes-opt-for-green-cement-the-future-of-sustainable-construction-101654438674435.html',
#   'published_date': datetime.datetime(2022, 6, 5, 14, 37, 1),
#   'publisher': 'Hindustan Times',
#   'title': 'Go economical and eco-friendly by constructing home with Green '
#            'Cement - Hindustan Times'},
#  {'description': '<a '
#                  'href="https://www.zawya.com/en/press-release/companies-news/mondelez-marks-bold-step-forward-in-ambition-towards-net-emissions-target-pztc7gez" '
#                  'target="_blank">Mondelēz marks bold step forward in ambition '
#                  'towards net emissions target</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">ZAWYA</font>',
#   'link': 'https://www.zawya.com/en/press-release/companies-news/mondelez-marks-bold-step-forward-in-ambition-towards-net-emissions-target-pztc7gez',
#   'published_date': datetime.datetime(2022, 6, 5, 12, 17, 51),
#   'publisher': 'ZAWYA',
#   'title': 'Mondelēz marks bold step forward in ambition towards net emissions '
#            'target - ZAWYA'},
#  {'description': '<a '
#                  'href="https://www.prnewswire.com/news-releases/temasek-launches-genzero-an-investment-platform-company-aimed-at-accelerating-decarbonisation-globally-301561515.html" '
#                  'target="_blank">Temasek launches GenZero, an investment '
#                  'platform company aimed at accelerating decarbonisation '
#                  'globally</a>&nbsp;&nbsp;<font color="#6f6f6f">PR '
#                  'Newswire</font>',
#   'link': 'https://www.prnewswire.com/news-releases/temasek-launches-genzero-an-investment-platform-company-aimed-at-accelerating-decarbonisation-globally-301561515.html',
#   'published_date': datetime.datetime(2022, 6, 6, 4, 0),
#   'publisher': 'PR Newswire',
#   'title': 'Temasek launches GenZero, an investment platform company aimed at '
#            'accelerating decarbonisation globally - PR Newswire'},
#  {'description': '<a '
#                  'href="https://www.businesswire.com/news/home/20220531005376/en/IG-Wealth-Management-Works-With-Carbon-Streaming-Corporation-to-Deliver-Funds-That-Align-With-Global-Effort-to-Reach-Net-Zero" '
#                  'target="_blank">IG Wealth Management Works With Carbon '
#                  'Streaming Corporation to Deliver Funds That Align With '
#                  'Global Effort to Reach Net Zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Business Wire</font>',
#   'link': 'https://www.businesswire.com/news/home/20220531005376/en/IG-Wealth-Management-Works-With-Carbon-Streaming-Corporation-to-Deliver-Funds-That-Align-With-Global-Effort-to-Reach-Net-Zero',
#   'published_date': datetime.datetime(2022, 5, 31, 11, 0),
#   'publisher': 'Business Wire',
#   'title': 'IG Wealth Management Works With Carbon Streaming Corporation to '
#            'Deliver Funds That Align With Global Effort to Reach Net Zero - '
#            'Business Wire'},
#  {'description': '<a '
#                  'href="https://www.thenationalnews.com/world/2022/05/31/net-zero-claims-for-qatar-world-cup-not-credible/" '
#                  'target="_blank">Net zero claims for Qatar World Cup '
#                  'overpromised</a>&nbsp;&nbsp;<font color="#6f6f6f">The '
#                  'National</font>',
#   'link': 'https://www.thenationalnews.com/world/2022/05/31/net-zero-claims-for-qatar-world-cup-not-credible/',
#   'published_date': datetime.datetime(2022, 5, 31, 10, 5, 9),
#   'publisher': 'The National',
#   'title': 'Net zero claims for Qatar World Cup overpromised - The National'},
#  {'description': '<a '
#                  'href="https://committees.parliament.uk/committee/62/environmental-audit-committee/news/171191/the-role-of-the-financial-sector-in-the-uks-net-zero-transition-to-be-examined-by-mps-in-new-inquiry/" '
#                  'target="_blank">The role of the financial sector in the '
#                  "UK's net zero transition to be examined by MPs in new "
#                  'inquiry - Committees - UK Parliament</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Committees</font>',
#   'link': 'https://committees.parliament.uk/committee/62/environmental-audit-committee/news/171191/the-role-of-the-financial-sector-in-the-uks-net-zero-transition-to-be-examined-by-mps-in-new-inquiry/',
#   'published_date': datetime.datetime(2022, 5, 30, 9, 5, 44),
#   'publisher': 'Committees',
#   'title': "The role of the financial sector in the UK's net zero transition "
#            'to be examined by MPs in new inquiry - Committees - UK Parliament '
#            '- Committees'},
#  {'description': '<a '
#                  'href="https://www.greenpeace.org/international/story/54079/great-carbon-capture-scam/" '
#                  'target="_blank">The Great Carbon Capture '
#                  'Scam</a>&nbsp;&nbsp;<font color="#6f6f6f">Greenpeace '
#                  'International</font>',
#   'link': 'https://www.greenpeace.org/international/story/54079/great-carbon-capture-scam/',
#   'published_date': datetime.datetime(2022, 6, 1, 23, 50, 52),
#   'publisher': 'Greenpeace International',
#   'title': 'The Great Carbon Capture Scam - Greenpeace International'},
#  {'description': '<a '
#                  'href="https://www.telegraphindia.com/jharkhand/ranchi-consensus-on-carbon-neutrality-drive/cid/1867893" '
#                  'target="_blank">Ranchi consensus on carbon neutrality '
#                  'drive</a>&nbsp;&nbsp;<font color="#6f6f6f">Telegraph '
#                  'India</font>',
#   'link': 'https://www.telegraphindia.com/jharkhand/ranchi-consensus-on-carbon-neutrality-drive/cid/1867893',
#   'published_date': datetime.datetime(2022, 6, 1, 21, 43, 16),
#   'publisher': 'Telegraph India',
#   'title': 'Ranchi consensus on carbon neutrality drive - Telegraph India'},
#  {'description': '<a '
#                  'href="https://www.tribuneindia.com/news/nation/pm-modi-ethanol-target-met-zero-emission-next-goal-401280" '
#                  'target="_blank">PM Modi: Ethanol target met, zero emission '
#                  'next goal</a>&nbsp;&nbsp;<font color="#6f6f6f">The Tribune '
#                  'India</font>',
#   'link': 'https://www.tribuneindia.com/news/nation/pm-modi-ethanol-target-met-zero-emission-next-goal-401280',
#   'published_date': datetime.datetime(2022, 6, 6, 0, 1),
#   'publisher': 'The Tribune India',
#   'title': 'PM Modi: Ethanol target met, zero emission next goal - The Tribune '
#            'India'},
#  {'description': '<a '
#                  'href="https://renews.biz/78224/net-zero-steel-group-issues-policy-guidelines/" '
#                  'target="_blank">Net zero steel group issues policy '
#                  'guidelines</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">reNEWS</font>',
#   'link': 'https://renews.biz/78224/net-zero-steel-group-issues-policy-guidelines/',
#   'published_date': datetime.datetime(2022, 6, 2, 8, 24, 20),
#   'publisher': 'reNEWS',
#   'title': 'Net zero steel group issues policy guidelines - reNEWS'},
#  {'description': '<a '
#                  'href="https://www.news18.com/news/opinion/with-global-south-in-jeopardy-developed-countries-must-take-lead-in-achieving-net-zero-emissions-5314123.html" '
#                  'target="_blank">With Global South in Jeopardy, Developed '
#                  'Countries Must Take Lead in Achieving Net Zero '
#                  'Emissions</a>&nbsp;&nbsp;<font color="#6f6f6f">News18</font>',
#   'link': 'https://www.news18.com/news/opinion/with-global-south-in-jeopardy-developed-countries-must-take-lead-in-achieving-net-zero-emissions-5314123.html',
#   'published_date': datetime.datetime(2022, 6, 5, 6, 25),
#   'publisher': 'News18',
#   'title': 'With Global South in Jeopardy, Developed Countries Must Take Lead '
#            'in Achieving Net Zero Emissions - News18'},
#  {'description': '<a '
#                  'href="https://economictimes.indiatimes.com/industry/renewables/transformative-collective-actions-to-build-sustainable-future/articleshow/92010157.cms" '
#                  'target="_blank">How to build a sustainable future through '
#                  'collective, transformative action</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Economic Times</font>',
#   'link': 'https://economictimes.indiatimes.com/industry/renewables/transformative-collective-actions-to-build-sustainable-future/articleshow/92010157.cms',
#   'published_date': datetime.datetime(2022, 6, 4, 17, 20),
#   'publisher': 'Economic Times',
#   'title': 'How to build a sustainable future through collective, '
#            'transformative action - Economic Times'},
#  {'description': '<a '
#                  'href="https://www.sdxcentral.com/articles/news/telefonica-touts-internal-carbon-pricing-strategy/2022/06/" '
#                  'target="_blank">Telefónica Touts Internal Carbon Pricing '
#                  'Strategy</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">SDxCentral</font>',
#   'link': 'https://www.sdxcentral.com/articles/news/telefonica-touts-internal-carbon-pricing-strategy/2022/06/',
#   'published_date': datetime.datetime(2022, 6, 5, 18, 0, 48),
#   'publisher': 'SDxCentral',
#   'title': 'Telefónica Touts Internal Carbon Pricing Strategy - SDxCentral'},
#  {'description': '<a href="http://wam.ae/en/details/1395303054756" '
#                  'target="_blank">Local Press: UAE shines in the war against '
#                  'climate change</a>&nbsp;&nbsp;<font color="#6f6f6f">Emirates '
#                  'News Agency</font>',
#   'link': 'http://wam.ae/en/details/1395303054756',
#   'published_date': datetime.datetime(2022, 6, 6, 4, 48),
#   'publisher': 'Emirates News Agency',
#   'title': 'Local Press: UAE shines in the war against climate change - '
#            'Emirates News Agency'},
#  {'description': '<a '
#                  'href="https://www.business-standard.com/article/current-affairs/world-economic-forum-2022-global-leaders-pledge-to-green-their-economies-122053101635_1.html" '
#                  'target="_blank">World Economic Forum 2022: Global leaders '
#                  'pledge to green their economies</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Business Standard</font>',
#   'link': 'https://www.business-standard.com/article/current-affairs/world-economic-forum-2022-global-leaders-pledge-to-green-their-economies-122053101635_1.html',
#   'published_date': datetime.datetime(2022, 6, 1, 0, 40),
#   'publisher': 'Business Standard',
#   'title': 'World Economic Forum 2022: Global leaders pledge to green their '
#            'economies - Business Standard'},
#  {'description': '<a '
#                  'href="https://news.microsoft.com/2022/06/02/accenture-microsoft-and-avanade-expand-partnership-to-help-organizations-tackle-their-greatest-sustainability-challenges/" '
#                  'target="_blank">Accenture, Microsoft and Avanade expand '
#                  'partnership to help organizations tackle their greatest '
#                  'sustainability challenges - Stories</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Microsoft</font>',
#   'link': 'https://news.microsoft.com/2022/06/02/accenture-microsoft-and-avanade-expand-partnership-to-help-organizations-tackle-their-greatest-sustainability-challenges/',
#   'published_date': datetime.datetime(2022, 6, 2, 12, 5, 19),
#   'publisher': 'Microsoft',
#   'title': 'Accenture, Microsoft and Avanade expand partnership to help '
#            'organizations tackle their greatest sustainability challenges - '
#            'Stories - Microsoft'},
#  {'description': '<a '
#                  'href="https://www.thenationalnews.com/business/road-to-net-zero/2022/06/04/carbon-dioxide-in-earths-atmosphere-rises-to-levels-not-seen-in-more-than-4-million-years/" '
#                  'target="_blank">Carbon dioxide in Earth\'s atmosphere rises '
#                  'to levels not seen in more than 4 million '
#                  'years</a>&nbsp;&nbsp;<font color="#6f6f6f">The '
#                  'National</font>',
#   'link': 'https://www.thenationalnews.com/business/road-to-net-zero/2022/06/04/carbon-dioxide-in-earths-atmosphere-rises-to-levels-not-seen-in-more-than-4-million-years/',
#   'published_date': datetime.datetime(2022, 6, 4, 10, 59, 13),
#   'publisher': 'The National',
#   'title': "Carbon dioxide in Earth's atmosphere rises to levels not seen in "
#            'more than 4 million years - The National'},
#  {'description': '<a '
#                  'href="https://www.bbc.com/news/uk-england-bristol-61659300" '
#                  'target="_blank">Bristol carbon emissions: Electric bus fleet '
#                  'to be introduced</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">BBC</font>',
#   'link': 'https://www.bbc.com/news/uk-england-bristol-61659300',
#   'published_date': datetime.datetime(2022, 6, 3, 8, 45, 26),
#   'publisher': 'BBC',
#   'title': 'Bristol carbon emissions: Electric bus fleet to be introduced - '
#            'BBC'},
#  {'description': '<a '
#                  'href="https://agsiw.org/gulf-net-zero-pledges-in-a-challenging-global-energy-security-environment/" '
#                  'target="_blank">Gulf Net-Zero Pledges in a Challenging '
#                  'Global Energy Security Environment</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Arab Gulf States Institute in '
#                  'Washington</font>',
#   'link': 'https://agsiw.org/gulf-net-zero-pledges-in-a-challenging-global-energy-security-environment/',
#   'published_date': datetime.datetime(2022, 6, 1, 8, 2, 21),
#   'publisher': 'Arab Gulf States Institute in Washington',
# ...
#   'title': 'Net Zero is a Stalinist fantasy - spiked - Spiked'},
#  {'description': '<a '
#                  'href="https://www.openaccessgovernment.org/volunteering-is-vital-to-the-uks-environmental-and-social-goals/136916/" '
#                  'target="_blank">Volunteering is vital to the UK\'s '
#                  'environmental and social goals</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Open Access Government</font>',
#   'link': 'https://www.openaccessgovernment.org/volunteering-is-vital-to-the-uks-environmental-and-social-goals/136916/',
#   'published_date': datetime.datetime(2022, 6, 1, 8, 41, 32),
#   'publisher': 'Open Access Government',
#   'title': "Volunteering is vital to the UK's environmental and social goals - "
#            'Open Access Government'},
#  {'description': '<a '
#                  'href="https://www.sfchronicle.com/opinion/openforum/article/Big-Oil-17216224.php" '
#                  'target="_blank">How to force Big Oil to pay for carbon '
#                  'cleanup</a>&nbsp;&nbsp;<font color="#6f6f6f">San Francisco '
#                  'Chronicle</font>',
#   'link': 'https://www.sfchronicle.com/opinion/openforum/article/Big-Oil-17216224.php',
#   'published_date': datetime.datetime(2022, 6, 3, 11, 11, 21),
#   'publisher': 'San Francisco Chronicle',
#   'title': 'How to force Big Oil to pay for carbon cleanup - San Francisco '
#            'Chronicle'},
#  {'description': '<a '
#                  'href="https://www.thomasnet.com/insights/apple-fedex-more-industrial-companies-working-toward-becoming-carbon-neutral/" '
#                  'target="_blank">Apple, FedEx, More Industrial Companies '
#                  'Working Toward Becoming Carbon Neutral</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">ThomasNet News</font>',
#   'link': 'https://www.thomasnet.com/insights/apple-fedex-more-industrial-companies-working-toward-becoming-carbon-neutral/',
#   'published_date': datetime.datetime(2022, 6, 2, 4, 15, 43),
#   'publisher': 'ThomasNet News',
#   'title': 'Apple, FedEx, More Industrial Companies Working Toward Becoming '
#            'Carbon Neutral - ThomasNet News'},
#  {'description': '<a '
#                  'href="https://www.hampshirechronicle.co.uk/news/20186653.help-support-winchester-businesses-begin-journey-net-zero/" '
#                  'target="_blank">Help to support Winchester businesses begin '
#                  'the journey to net zero</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Hampshire Chronicle</font>',
#   'link': 'https://www.hampshirechronicle.co.uk/news/20186653.help-support-winchester-businesses-begin-journey-net-zero/',
#   'published_date': datetime.datetime(2022, 6, 5, 4, 0),
#   'publisher': 'Hampshire Chronicle',
#   'title': 'Help to support Winchester businesses begin the journey to net '
#            'zero - Hampshire Chronicle'},
#  {'description': '<a '
#                  'href="https://www.livemint.com/news/india/mumbai-announces-net-zero-carbon-emission-plans-by-2050-two-decades-ahead-of-country-s-target-11647175192128.html" '
#                  'target="_blank">Mumbai announces net-zero carbon emission '
#                  "plans by 2050, two decades ahead of country's target | "
#                  'Mint</a>&nbsp;&nbsp;<font color="#6f6f6f">Mint</font>',
#   'link': 'https://www.livemint.com/news/india/mumbai-announces-net-zero-carbon-emission-plans-by-2050-two-decades-ahead-of-country-s-target-11647175192128.html',
#   'published_date': datetime.datetime(2022, 3, 13, 8, 0),
#   'publisher': 'Mint',
#   'title': 'Mumbai announces net-zero carbon emission plans by 2050, two '
#            "decades ahead of country's target | Mint - Mint"},
#  {'description': '<a '
#                  'href="https://theprint.in/environment/steel-to-cement-climate-change-has-a-neglected-focus-area-industries-need-to-take-note/982295/" '
#                  'target="_blank">Steel to cement—Climate change has a '
#                  'neglected focus area. Industries need to take '
#                  'note</a>&nbsp;&nbsp;<font color="#6f6f6f">ThePrint</font>',
#   'link': 'https://theprint.in/environment/steel-to-cement-climate-change-has-a-neglected-focus-area-industries-need-to-take-note/982295/',
#   'published_date': datetime.datetime(2022, 6, 5, 9, 30, 34),
#   'publisher': 'ThePrint',
#   'title': 'Steel to cement—Climate change has a neglected focus area. '
#            'Industries need to take note - ThePrint'},
#  {'description': '<a '
#                  'href="https://www.financialexpress.com/infrastructure/airlines-aviation/powering-aviations-net-zero-future-with-sustainable-aviation-fuel-and-efficient-jet-engine/2543696/" '
#                  'target="_blank">Powering aviation’s net-zero future with '
#                  'sustainable aviation fuel and efficient jet '
#                  'engine</a>&nbsp;&nbsp;<font color="#6f6f6f">The Financial '
#                  'Express</font>',
#   'link': 'https://www.financialexpress.com/infrastructure/airlines-aviation/powering-aviations-net-zero-future-with-sustainable-aviation-fuel-and-efficient-jet-engine/2543696/',
#   'published_date': datetime.datetime(2022, 5, 31, 13, 47, 35),
#   'publisher': 'The Financial Express',
#   'title': 'Powering aviation’s net-zero future with sustainable aviation fuel '
#            'and efficient jet engine - The Financial Express'},
#  {'description': '<a '
#                  'href="https://www.theguardian.com/environment/ng-interactive/2022/may/11/fossil-fuel-carbon-bombs-climate-breakdown-oil-gas" '
#                  'target="_blank">Revealed: the \'carbon bombs\' set to '
#                  'trigger catastrophic climate breakdown</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Guardian</font>',
#   'link': 'https://www.theguardian.com/environment/ng-interactive/2022/may/11/fossil-fuel-carbon-bombs-climate-breakdown-oil-gas',
#   'published_date': datetime.datetime(2022, 5, 11, 7, 0),
#   'publisher': 'The Guardian',
#   'title': "Revealed: the 'carbon bombs' set to trigger catastrophic climate "
#            'breakdown - The Guardian'},
#  {'description': '<a '
#                  'href="https://www.brookings.edu/blog/planetpolicy/2021/10/25/net-zero-carbon-pledges-have-good-intentions-but-they-are-not-enough/" '
#                  'target="_blank">Net zero carbon pledges have good '
#                  'intentions. But they are not enough.</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Brookings Institution</font>',
#   'link': 'https://www.brookings.edu/blog/planetpolicy/2021/10/25/net-zero-carbon-pledges-have-good-intentions-but-they-are-not-enough/',
#   'published_date': datetime.datetime(2021, 10, 25, 7, 0),
#   'publisher': 'Brookings Institution',
#   'title': 'Net zero carbon pledges have good intentions. But they are not '
#            'enough. - Brookings Institution'},
#  {'description': '<a '
#                  'href="https://www.thehindubusinessline.com/news/india-committed-to-achieving-net-zero-carbon-emission-by-2070-says-modi/article37293537.ece" '
#                  'target="_blank">India committed to achieving net-zero carbon '
#                  'emission by 2070, says Modi</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">BusinessLine</font>',
#   'link': 'https://www.thehindubusinessline.com/news/india-committed-to-achieving-net-zero-carbon-emission-by-2070-says-modi/article37293537.ece',
#   'published_date': datetime.datetime(2021, 11, 1, 7, 0),
#   'publisher': 'BusinessLine',
#   'title': 'India committed to achieving net-zero carbon emission by 2070, '
#            'says Modi - BusinessLine'},
#  {'description': '<a '
#                  'href="https://theprint.in/science/researchers-develop-capturing-system-to-efficiently-extract-carbon-dioxide-from-environment/983909/" '
#                  'target="_blank">Researchers develop capturing system to '
#                  'efficiently extract carbon dioxide from '
#                  'environment</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">ThePrint</font>',
#   'link': 'https://theprint.in/science/researchers-develop-capturing-system-to-efficiently-extract-carbon-dioxide-from-environment/983909/',
#   'published_date': datetime.datetime(2022, 6, 4, 17, 15, 12),
#   'publisher': 'ThePrint',
#   'title': 'Researchers develop capturing system to efficiently extract carbon '
#            'dioxide from environment - ThePrint'},
#  {'description': '<a '
#                  'href="https://english.sakshi.com/news/national/her-circle-paves-way-sustainability-india-s-first-carbon-neutral-photoshoot-156137" '
#                  'target="_blank">Her Circle Paves the Way for Sustainability '
#                  'With India’s First Carbon-Neutral '
#                  'Photoshoot</a>&nbsp;&nbsp;<font color="#6f6f6f">Sakshi '
#                  'Post</font>',
#   'link': 'https://english.sakshi.com/news/national/her-circle-paves-way-sustainability-india-s-first-carbon-neutral-photoshoot-156137',
#   'published_date': datetime.datetime(2022, 6, 5, 8, 1, 18),
#   'publisher': 'Sakshi Post',
#   'title': 'Her Circle Paves the Way for Sustainability With India’s First '
#            'Carbon-Neutral Photoshoot - Sakshi Post'},
#  {'description': '<a '
#                  'href="https://www.theenergymix.com/2022/06/01/u-s-rules-could-change-the-way-canadian-fossils-report-carbon-emissions/" '
#                  'target="_blank">US Rules Could Change the Way Canadian '
#                  'Fossils Report Carbon Emissions</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Energy Mix</font>',
#   'link': 'https://www.theenergymix.com/2022/06/01/u-s-rules-could-change-the-way-canadian-fossils-report-carbon-emissions/',
#   'published_date': datetime.datetime(2022, 6, 1, 4, 19, 26),
#   'publisher': 'The Energy Mix',
#   'title': 'US Rules Could Change the Way Canadian Fossils Report Carbon '
#            'Emissions - The Energy Mix'},
#  {'description': '<a '
#                  'href="https://www.weforum.org/agenda/2022/02/net-zero-risks-benefits-climate/" '
#                  'target="_blank">The risks and benefits for companies going '
#                  'net zero</a>&nbsp;&nbsp;<font color="#6f6f6f">World Economic '
#                  'Forum</font>',
#   'link': 'https://www.weforum.org/agenda/2022/02/net-zero-risks-benefits-climate/',
#   'published_date': datetime.datetime(2022, 2, 28, 8, 0),
#   'publisher': 'World Economic Forum',
#   'title': 'The risks and benefits for companies going net zero - World '
#            'Economic Forum'},
#  {'description': '<a '
#                  'href="https://www.news18.com/news/opinion/indias-path-to-clean-transport-is-electric-strong-central-policies-on-zero-emission-vehicles-5313373.html" '
#                  'target="_blank">India’s Path to Clean Transport is Electric, '
#                  'Strong Central Policies on Zero-Emission '
#                  'Vehicles</a>&nbsp;&nbsp;<font color="#6f6f6f">News18</font>',
#   'link': 'https://www.news18.com/news/opinion/indias-path-to-clean-transport-is-electric-strong-central-policies-on-zero-emission-vehicles-5313373.html',
#   'published_date': datetime.datetime(2022, 6, 5, 3, 54),
#   'publisher': 'News18',
#   'title': 'India’s Path to Clean Transport is Electric, Strong Central '
#            'Policies on Zero-Emission Vehicles - News18'},
#  {'description': '<a '
#                  'href="https://www.thehindu.com/sci-tech/energy-and-environment/india-needs-101tn-investment-to-achieve-net-zero-emission-by-2070-study/article37554977.ece" '
#                  'target="_blank">India needs about $10 trillion to meet net '
#                  'zero target, says study</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Hindu</font>',
#   'link': 'https://www.thehindu.com/sci-tech/energy-and-environment/india-needs-101tn-investment-to-achieve-net-zero-emission-by-2070-study/article37554977.ece',
#   'published_date': datetime.datetime(2021, 11, 18, 8, 0),
#   'publisher': 'The Hindu',
#   'title': 'India needs about $10 trillion to meet net zero target, says study '
#            '- The Hindu'},
#  {'description': '<a '
#                  'href="https://www.thehindu.com/news/national/india-rejects-net-zero-carbon-emissions-target-says-pathway-more-important/article37206063.ece" '
#                  'target="_blank">India rejects net zero carbon emissions '
#                  'target, says pathway more important</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">The Hindu</font>',
#   'link': 'https://www.thehindu.com/news/national/india-rejects-net-zero-carbon-emissions-target-says-pathway-more-important/article37206063.ece',
#   'published_date': datetime.datetime(2021, 10, 28, 7, 0),
#   'publisher': 'The Hindu',
#   'title': 'India rejects net zero carbon emissions target, says pathway more '
#            'important - The Hindu'},
#  {'description': '<a '
#                  'href="https://timesofindia.indiatimes.com/blogs/voices/how-indian-startups-are-working-to-achieve-a-net-zero-carbon-emission-target/" '
#                  'target="_blank">How Indian startups are working to achieve a '
#                  'net-zero carbon emission target</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">Times of India</font>',
#   'link': 'https://timesofindia.indiatimes.com/blogs/voices/how-indian-startups-are-working-to-achieve-a-net-zero-carbon-emission-target/',
#   'published_date': datetime.datetime(2022, 3, 28, 7, 0),
#   'publisher': 'Times of India',
#   'title': 'How Indian startups are working to achieve a net-zero carbon '
#            'emission target - Times of India'},
#  {'description': '<a '
#                  'href="https://www.archdaily.com/978627/has-the-pandemic-halted-the-road-to-net-zero-carbon" '
#                  'target="_blank">Has the Pandemic Halted the Road to Net-Zero '
#                  'Carbon?</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">ArchDaily</font>',
#   'link': 'https://www.archdaily.com/978627/has-the-pandemic-halted-the-road-to-net-zero-carbon',
#   'published_date': datetime.datetime(2022, 3, 20, 7, 0),
#   'publisher': 'ArchDaily',
#   'title': 'Has the Pandemic Halted the Road to Net-Zero Carbon? - ArchDaily'},
#  {'description': '<a '
#                  'href="https://www.downtoearth.org.in/news/climate-change/agenda-for-cop26-how-to-achieve-net-zero-79878" '
#                  'target="_blank">Agenda for CoP26: How to achieve net '
#                  'zero</a>&nbsp;&nbsp;<font color="#6f6f6f">Down To Earth '
#                  'Magazine</font>',
#   'link': 'https://www.downtoearth.org.in/news/climate-change/agenda-for-cop26-how-to-achieve-net-zero-79878',
#   'published_date': datetime.datetime(2021, 10, 27, 7, 0),
#   'publisher': 'Down To Earth Magazine',
#   'title': 'Agenda for CoP26: How to achieve net zero - Down To Earth '
#            'Magazine'},
#  {'description': '<a '
#                  'href="https://www.edie.net/how-are-manufacturers-approaching-net-zero-and-the-green-recovery/" '
#                  'target="_blank">How are manufacturers approaching net-zero '
#                  'and the green recovery?</a>&nbsp;&nbsp;<font '
#                  'color="#6f6f6f">edie.net</font>',
#   'link': 'https://www.edie.net/how-are-manufacturers-approaching-net-zero-and-the-green-recovery/',
#   'published_date': datetime.datetime(2020, 9, 29, 7, 0),
#   'publisher': 'edie.net',
#   'title': 'How are manufacturers approaching net-zero and the green recovery? '
#            '- edie.net'},
#  {'description': '<a '
#                  'href="https://scroll.in/article/1013340/states-have-an-important-role-to-play-as-india-sets-sights-on-net-zero-carbon-emissions-by-2070" '
#                  'target="_blank">States have an important role to play as '
#                  'India sets sights on net zero carbon emissions by '
#                  '2070</a>&nbsp;&nbsp;<font color="#6f6f6f">Scroll.in</font>',
#   'link': 'https://scroll.in/article/1013340/states-have-an-important-role-to-play-as-india-sets-sights-on-net-zero-carbon-emissions-by-2070',
#   'published_date': datetime.datetime(2022, 1, 22, 8, 0),
#   'publisher': 'Scroll.in',
#   'title': 'States have an important role to play as India sets sights on net '
#            'zero carbon emissions by 2070 - Scroll.in'}]
